# %%
# import required libraries 

from birdnetlib import Recording
from birdnetlib.analyzer import Analyzer
from datetime import datetime
from pathlib import Path
from dataclasses import dataclass, asdict
from typing import List, Optional
import json
# Out:
# C:\Users\mhrynyk\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
# set paths to .wav files

# example .wav file - this is used to test that birdnet analyzer function is running
example = r"Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230807_041900.wav"

# folder containing multiple .wav files for analysis
aru_dir = Path(r"Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles")

# %%
# run single example .wav file
# NOTE: lat, long, datetime, and confidence need to be manually entered

# Load and initialize the BirdNET-Analyzer models.
analyzer = Analyzer()

recording = Recording(
    analyzer,
    example,
    lat=42.57924949,
    lon=-80.45464671,
    date=datetime(year=2023, month=8, day=7), # use date or week_48
    min_conf=0.10,
)
recording.analyze()

print(recording.detections)
# Out:
# Labels loaded.
# load model True
# Model loaded.
# Labels loaded.
# load_species_list_model
# Meta model loaded.
# read_audio_data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\birdnetlib\main.py:251, in Recording.read_audio_data(self)
#     250 try:
# --> 251     self.ndarray, rate = librosa.load(
#     252         self.path, sr=SAMPLE_RATE, mono=True, res_type="kaiser_fast"
#     253     )
#     254     self.duration = librosa.get_duration(y=self.ndarray, sr=SAMPLE_RATE)
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\librosa\core\audio.py:175, in load(path, sr, mono, offset, duration, dtype, res_type)
#     174 try:
# --> 175     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     177 except sf.SoundFileRuntimeError as exc:
#     178     # If soundfile failed, try audioread instead
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\librosa\core\audio.py:221, in __soundfile_load(path, offset, duration, dtype)
#     220     # Load the target number of frames, and transpose to match librosa form
# --> 221     y = sf_desc.read(frames=frame_duration, dtype=dtype, always_2d=False).T
#     223 return y, sr_native
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\soundfile.py:895, in SoundFile.read(self, frames, dtype, always_2d, fill_value, out)
#     894         frames = len(out)
# --> 895 frames = self._array_io('read', out, frames)
#     896 if len(out) > frames:
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\soundfile.py:1344, in SoundFile._array_io(self, action, array, frames)
#    1343 cdata = _ffi.cast(ctype + '*', array.__array_interface__['data'][0])
# -> 1344 return self._cdata_io(action, cdata, ctype, frames)
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\soundfile.py:1353, in SoundFile._cdata_io(self, action, data, ctype, frames)
#    1352 func = getattr(_snd, 'sf_' + action + 'f_' + ctype)
# -> 1353 frames = func(self._file, data, frames)
#    1354 _error_check(self._errorcode)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AudioFormatError                          Traceback (most recent call last)
# Cell In[14], line 15
#       5 analyzer = Analyzer()
#       7 recording = Recording(
#       8     analyzer,
#       9     example,
#    (...)
#      13     min_conf=0.10,
#      14 )
# ---> 15 recording.analyze()
#      17 print(recording.detections)
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\birdnetlib\main.py:56, in RecordingBase.analyze(self)
#      53     self.week_48 = return_week_48_from_datetime(self.date)
#      55 # Read and analyze.
# ---> 56 self.read_audio_data()
#      57 self.analyzer.analyze_recording(self)
#      58 self.analyzed = True
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\birdnetlib\main.py:263, in Recording.read_audio_data(self)
#     261 except BaseException as e:
#     262     print(e)
# --> 263     raise AudioFormatError("Generic audio read error occurred from librosa.")
#     265 self.process_audio_data(rate)
#
# AudioFormatError: Generic audio read error occurred from librosa.

# %%
## ****** Code below runs multiple wav files from a dir

# %%
# get wav files from dir
wav_files = list(aru_dir.glob("**/*.wav"))
print('wav files to be analyzed: ' + str(len(wav_files)))

for wav_file in wav_files:
    print(wav_file)
# Out:
# wav files to be analyzed: 120
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230807_041900.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230807_061906.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230807_183400.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230807_203406.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230808_042000.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230808_062006.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230808_183300.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230808_203306.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230809_042100.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230809_062106.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230809_183200.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230809_203206.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230810_042200.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230810_062206.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230810_183000.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230810_203006.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230811_042300.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230811_062306.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230811_182900.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230811_202906.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230812_042400.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230812_062407.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230812_182700.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230812_202706.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\A_13122\Data\S4A13122_20230813_042600.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\B_13122\Data\S4A13122_20230813_062609.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\B_13122\Data\S4A13122_20230813_182600.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\B_13122\Data\S4A13122_20230813_202606.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\B_13122\Data\S4A13122_20230814_042700.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC1_13122\B_13122\Data\S4A13122_20230814_062706.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230807_041900.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230807_061906.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230807_183400.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230807_203406.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230808_042000.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230808_062006.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230808_183300.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230808_203306.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230809_042100.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230809_062106.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230809_183200.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230809_203206.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230810_042200.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230810_062206.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230810_183000.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230810_203006.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230811_042300.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230811_062306.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230811_182900.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230811_202906.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230812_042400.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230812_062406.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230812_182700.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230812_202706.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\A_13137\Data\S4A13137_20230813_042600.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\B_13137\Data\S4A13137_20230813_062610.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\B_13137\Data\S4A13137_20230813_182600.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\B_13137\Data\S4A13137_20230813_202606.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\B_13137\Data\S4A13137_20230814_042700.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPC2_13137\B_13137\Data\S4A13137_20230814_062706.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230807_041900.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230807_061906.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230807_183400.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230807_203406.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230808_042000.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230808_062006.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230808_183300.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230808_203306.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230809_042100.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230809_062106.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230809_183200.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230809_203206.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230810_042200.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230810_062206.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230810_183000.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230810_203006.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230811_042300.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230811_062306.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230811_182900.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230811_202906.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230812_042400.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230812_062406.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230812_182700.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230812_202706.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\A_15872\Data\S4A15872_20230813_042600.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\B_15872\Data\S4A15872_20230813_062610.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\B_15872\Data\S4A15872_20230813_182600.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\B_15872\Data\S4A15872_20230813_202607.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\B_15872\Data\S4A15872_20230814_042700.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT1_15872\B_15872\Data\S4A15872_20230814_062706.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230807_041900.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230807_061906.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230807_183400.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230807_203406.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230808_042000.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230808_062006.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230808_183300.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230808_203306.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230809_042100.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230809_062106.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230809_183200.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230809_203206.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230810_042200.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230810_062206.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230810_183000.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230810_203006.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230811_042300.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230811_062306.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230811_182900.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230811_202906.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230812_042400.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230812_062406.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230812_182700.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230812_202706.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\A_01315\Data\S4A01315_20230813_042600.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\B_01315\Data\S4A01315_20230813_062610.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\B_01315\Data\S4A01315_20230813_182600.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\B_01315\Data\S4A01315_20230813_202606.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\B_01315\Data\S4A01315_20230814_042700.wav
# Y:\LP_birds\LP_birds_2023\ARUs\ARU_audiofiles\LPT2_01315\B_01315\Data\S4A01315_20230814_062706.wav

# %%
# create an audio recording class
# class is a 'blueprint' for creating objects (i.e. instance of a class)

@dataclass
class AudioRecording:
    path: Path
    lat: float
    lon: float
    min_conf: float
    aru_id: str

    # populated later
    detections: Optional[List] = None
    date: Optional[datetime] = None

    def __post_init__(self):
        self.date = datetime.strptime(self.path.with_suffix("").name.split("_", 1)[1], "%Y%m%d_%H%M%S")

    def to_json(self, file_path):
        data = asdict(self)
        with open(file_path, 'w') as json_file:
            json.dump(data, json_file, default=str, indent=4)

# %%
# run analysis on 

audio_recordings = []
for wav_file in wav_files:
    audio_recording = AudioRecording(
        path=wav_file,
        lat=42.58808112, # exact ARU location or can provide general 
        lon=-80.44651377, # exact ARU location or can provide general 
        min_conf=0.10, # confidence 
        aru_id=wav_file.parts[-3] # must be manually changed (eg. "LPT2_01315") or use wav_file.parts[-3]
    )
    analyzer = Analyzer()
    recording = Recording(
        analyzer,
        audio_recording.path,
        lat=audio_recording.lat,
        lon=audio_recording.lon,
        date=audio_recording.date,
        min_conf=audio_recording.min_conf
    )
    recording.analyze()
    audio_recording.detections = recording.detections
    audio_recording.to_json(recording.path.with_suffix(".json"))

    audio_recordings.append(audio_recording)
# Out:
# Labels loaded.
# load model True
# Model loaded.
# Labels loaded.
# load_species_list_model
# Meta model loaded.
# read_audio_data
# read_audio_data: complete, read  2397 chunks.
# analyze_recording S4A01315_20230813_062610.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# return_predicted_species_list
# 30
# 98 species loaded.
# Labels loaded.
# load model True
# Model loaded.
# Labels loaded.
# load_species_list_model
# Meta model loaded.
# read_audio_data
# read_audio_data: complete, read  2400 chunks.
# analyze_recording S4A01315_20230813_182600.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# return_predicted_species_list
# 30
# 98 species loaded.
# Labels loaded.
# load model True
# Model loaded.
# Labels loaded.
# load_species_list_model
# Meta model loaded.
# read_audio_data
# read_audio_data: complete, read  2398 chunks.
# analyze_recording S4A01315_20230813_202606.wav
# recording has lon/lat
# set_predicted_species_list_from_position
# return_predicted_species_list
# 30
# 98 species loaded.
# Labels loaded.
# load model True
# Model loaded.
# Labels loaded.
# load_species_list_model
# Meta model loaded.
# read_audio_data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\birdnetlib\main.py:251, in Recording.read_audio_data(self)
#     250 try:
# --> 251     self.ndarray, rate = librosa.load(
#     252         self.path, sr=SAMPLE_RATE, mono=True, res_type="kaiser_fast"
#     253     )
#     254     self.duration = librosa.get_duration(y=self.ndarray, sr=SAMPLE_RATE)
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\librosa\core\audio.py:175, in load(path, sr, mono, offset, duration, dtype, res_type)
#     174 try:
# --> 175     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#     177 except sf.SoundFileRuntimeError as exc:
#     178     # If soundfile failed, try audioread instead
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\librosa\core\audio.py:221, in __soundfile_load(path, offset, duration, dtype)
#     220     # Load the target number of frames, and transpose to match librosa form
# --> 221     y = sf_desc.read(frames=frame_duration, dtype=dtype, always_2d=False).T
#     223 return y, sr_native
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\soundfile.py:895, in SoundFile.read(self, frames, dtype, always_2d, fill_value, out)
#     894         frames = len(out)
# --> 895 frames = self._array_io('read', out, frames)
#     896 if len(out) > frames:
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\soundfile.py:1344, in SoundFile._array_io(self, action, array, frames)
#    1343 cdata = _ffi.cast(ctype + '*', array.__array_interface__['data'][0])
# -> 1344 return self._cdata_io(action, cdata, ctype, frames)
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\soundfile.py:1353, in SoundFile._cdata_io(self, action, data, ctype, frames)
#    1352 func = getattr(_snd, 'sf_' + action + 'f_' + ctype)
# -> 1353 frames = func(self._file, data, frames)
#    1354 _error_check(self._errorcode)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AudioFormatError                          Traceback (most recent call last)
# Cell In[12], line 21
#      12 analyzer = Analyzer()
#      13 recording = Recording(
#      14     analyzer,
#      15     audio_recording.path,
#    (...)
#      19     min_conf=audio_recording.min_conf
#      20 )
# ---> 21 recording.analyze()
#      22 audio_recording.detections = recording.detections
#      23 audio_recording.to_json(recording.path.with_suffix(".json"))
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\birdnetlib\main.py:56, in RecordingBase.analyze(self)
#      53     self.week_48 = return_week_48_from_datetime(self.date)
#      55 # Read and analyze.
# ---> 56 self.read_audio_data()
#      57 self.analyzer.analyze_recording(self)
#      58 self.analyzed = True
#
# File ~\Anaconda3\envs\ARU_CWS_analysis\lib\site-packages\birdnetlib\main.py:263, in Recording.read_audio_data(self)
#     261 except BaseException as e:
#     262     print(e)
# --> 263     raise AudioFormatError("Generic audio read error occurred from librosa.")
#     265 self.process_audio_data(rate)
#
# AudioFormatError: Generic audio read error occurred from librosa.
